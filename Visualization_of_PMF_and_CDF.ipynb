# %% [markdown]
# <a href="https://colab.research.google.com/github/PavanPk1/APICalls-ReactJs/blob/main/Visualization_of_PMF_and_CDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for PMF and CDF
X = np.array([0, 1, 2, 3])
PMF = np.array([1/8, 3/8, 3/8, 1/8])
CDF = np.cumsum(PMF)

# Plot PMF
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.bar(X, PMF, color='blue', alpha=0.7)
plt.title('Probability Mass Function (PMF)')
plt.xlabel('Number of Heads')
plt.ylabel('Probability')
plt.xticks(X)

# Plot CDF
plt.subplot(1, 2, 2)
plt.bar(X, CDF, color='green', alpha=0.7)
plt.title('Cumulative Distribution Function (CDF)')
plt.xlabel('Number of Heads')
plt.ylabel('Cumulative Probability')
plt.xticks(X)
plt.tight_layout()
plt.show()
